# %%
# Import the required libraries and dependencies
import pandas as pd
import hvplot.pandas
from pathlib import Path
import panel as pn
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
pn.extension(comms='vscode')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
pip install jupyter_bokeh
# Out:
# Requirement already satisfied: jupyter_bokeh in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (3.0.7)
# Requirement already satisfied: bokeh==3.* in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from jupyter_bokeh) (3.2.1)
# Requirement already satisfied: ipywidgets==8.* in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from jupyter_bokeh) (8.0.4)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.0.5)
# Requirement already satisfied: numpy>=1.16 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (23.1)
# Requirement already satisfied: pandas>=1.2 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2.0.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (9.4.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.3.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2022.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (6.25.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (3.0.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (1.5.6)
# Requirement already satisfied: psutil in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (23.2.0)
# Requirement already satisfied: backcall in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: decorator in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: exceptiongroup in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (1.0.4)
# Requirement already satisfied: colorama in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from Jinja2>=2.9->bokeh==3.*->jupyter_bokeh) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (305.1)
# Requirement already satisfied: wcwidth in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh==3.*->jupyter_bokeh) (1.16.0)
# Requirement already satisfied: executing in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\aniru\.conda\envs\alpacaenv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Import the Data

# %%
# Using the read_csv function and Path module, create a DataFrame 

sfo_data_df=pd.read_csv(Path("sfo_neighborhoods_census_data.csv"))
display(sfo_data_df.head())
display(sfo_data_df.tail())
# Out:
#    year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 0  2010      Alamo Square           291.182945         372560        1239
# 1  2010        Anza Vista           267.932583         372560        1239
# 2  2010           Bayview           170.098665         372560        1239
# 3  2010  Buena Vista Park           347.394919         372560        1239
# 4  2010  Central Richmond           319.027623         372560        1239
#      year            neighborhood  sale_price_sqr_foot  housing_units  \
# 392  2016          Telegraph Hill           903.049771         384242
# 393  2016              Twin Peaks           970.085470         384242
# 394  2016  Van Ness/ Civic Center           552.602567         384242
# 395  2016       Visitacion Valley           328.319007         384242
# 396  2016           Westwood Park           631.195426         384242
#
#      gross_rent
# 392        4390
# 393        4390
# 394        4390
# 395        4390
# 396        4390

# %% [markdown]
# ## Calculating and Plotting the Housing Units per Year

# %%
# Create a numerical aggregation that groups the data by the year and then averages the results.
housing_units_by_year = sfo_data_df.groupby("year").mean(["housing_units","gross_rent","sale_price_sqr_foot"])
housing_units_by_year
# Out:
#       sale_price_sqr_foot  housing_units  gross_rent
# year
# 2010           369.344353       372560.0      1239.0
# 2011           341.903429       374507.0      1530.0
# 2012           399.389968       376454.0      2324.0
# 2013           483.600304       378401.0      2971.0
# 2014           556.277273       380348.0      3528.0
# 2015           632.540352       382295.0      3739.0
# 2016           697.643709       384242.0      4390.0

# %% [markdown]
# ##  Using the hvplot function to plot the housing_units_by_year DataFrame as a bar chart. Making the x-axis represent the year and the y-axis represent the housing_units.

# %% [markdown]
# ### Styling and formatting the line plot to ensure a professionally styled visualization.

# %%
# Creating a visual aggregation explore the housing units by year
housing_units_by_year.hvplot.bar(x="year", y="housing_units", title="Housing units in SFO from 2010 to2016", color="blue",xlabel="Year", ylabel="Housing Units",yformatter='%0f')
# Out:
# :Bars   [year]   (housing_units)

# %% [markdown]
# ## There has been an increase in housing units every year, but the increase every year is small

# %% [markdown]
# ## Calculating and Plotting the Average Sale Prices per Square Foot

# %%
# Create a numerical aggregation by grouping the data by year and averaging the results
prices_square_foot_by_year = sfo_data_df.groupby("year").mean(["housing_units","gross_rent","sale_price_sqr_foot"])
prices_square_foot_by_year
# Out:
#       sale_price_sqr_foot  housing_units  gross_rent
# year
# 2010           369.344353       372560.0      1239.0
# 2011           341.903429       374507.0      1530.0
# 2012           399.389968       376454.0      2324.0
# 2013           483.600304       378401.0      2971.0
# 2014           556.277273       380348.0      3528.0
# 2015           632.540352       382295.0      3739.0
# 2016           697.643709       384242.0      4390.0

# %% [markdown]
# ##  The lowest gross rent was 1239 in the year 2010

# %% [markdown]
# ## Creating a new DataFrame named prices_square_foot_by_year by filtering out the “housing_units” column. The new DataFrame includes the averages per year for only the sale price per square foot and the gross rent.

# %%
prices_square_foot_by_year=prices_square_foot_by_year[["sale_price_sqr_foot","gross_rent"]]
prices_square_foot_by_year
# Out:
#       sale_price_sqr_foot  gross_rent
# year
# 2010           369.344353      1239.0
# 2011           341.903429      1530.0
# 2012           399.389968      2324.0
# 2013           483.600304      2971.0
# 2014           556.277273      3528.0
# 2015           632.540352      3739.0
# 2016           697.643709      4390.0

# %% [markdown]
#  ## Using hvPlot to plot the prices_square_foot_by_year DataFrame as a line plot

# %% [markdown]
# ### Styling and formatting the line plot to ensure a professionally styled visualization

# %%
prices_square_foot_by_year.hvplot.line(xlabel='Year', ylabel='Gross Rent/Sale Price Per Square Foot',title="Sale Price Per Square Foot and Gross Rent in SFO from 2010-2016")
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %% [markdown]
# ## Using both the prices_square_foot_by_year DataFrame and interactive plots to answer the questions

# %% [markdown]
# ## The Sale Price dropped from 2010 to 2011

# %% [markdown]
# ## Yes, the gross rent did increase from 2010 to 2011

# %% [markdown]
# ## Compare the Average Sale Prices by Neighborhood

# %% [markdown]
# ### Creating a new DataFrame that groups the original DataFrame by year and neighborhood. Aggregating the results by the mean of the groups.

# %%
 #Group by year and neighborhood and then create a new dataframe of the mean values
prices_by_year_by_neighborhood=sfo_data_df.groupby(["year","neighborhood"]).mean(["housing_units","gross_rent","sale_price_sqr_foot"])
prices_by_year_by_neighborhood.head()
# Out:
#                        sale_price_sqr_foot  housing_units  gross_rent
# year neighborhood
# 2010 Alamo Square               291.182945       372560.0      1239.0
#      Anza Vista                 267.932583       372560.0      1239.0
#      Bayview                    170.098665       372560.0      1239.0
#      Buena Vista Park           347.394919       372560.0      1239.0
#      Central Richmond           319.027623       372560.0      1239.0

# %% [markdown]
# ###  Filtering out the “housing_units” column to create a DataFrame that includes only the sale_price_sqr_foot and gross_rent averages per year.

# %%
# Filter out the housing_units
prices_by_year_by_neighborhood =prices_by_year_by_neighborhood[["sale_price_sqr_foot","gross_rent"]]
display(prices_by_year_by_neighborhood.head())
display(prices_by_year_by_neighborhood.tail())
# Out:
#                        sale_price_sqr_foot  gross_rent
# year neighborhood
# 2010 Alamo Square               291.182945      1239.0
#      Anza Vista                 267.932583      1239.0
#      Bayview                    170.098665      1239.0
#      Buena Vista Park           347.394919      1239.0
#      Central Richmond           319.027623      1239.0
#                              sale_price_sqr_foot  gross_rent
# year neighborhood
# 2016 Telegraph Hill                   903.049771      4390.0
#      Twin Peaks                       970.085470      4390.0
#      Van Ness/ Civic Center           552.602567      4390.0
#      Visitacion Valley                328.319007      4390.0
#      Westwood Park                    631.195426      4390.0

# %% [markdown]
# ### Creating an interactive line plot with hvPlot that visualizes both sale_price_sqr_foot and gross_rent. Setting the x-axis parameter to the year (x="year"). Using the groupby parameter to create an interactive widget for neighborhood

# %% [markdown]
# #### Style and format the line plot to ensure a professionally styled visualization

# %%
prices_by_year_by_neighborhood.hvplot.line( x='year',xlabel='Year',ylabel="Gross Rent/ Sale price per square feet" ,groupby = "neighborhood", title=" Gross Rent and Sale price per Sqquare feet from 2010-2016")
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'608235cb-fd7f-4ea8-9784-c6acbb318cf4': {'version…

# %% [markdown]
# ## Use the interactive visualization to answer the following question

# %% [markdown]
# ## Read the neighborhood_coordinates.csv file from the Resources folder into the notebook, and create a DataFrame named neighborhood_locations_df. Be sure to set the index_col of the DataFrame as “Neighborhood”.

# %%
# Load neighborhoods coordinates data
neighborhood_locations_df=pd.read_csv(Path("neighborhoods_coordinates.csv"), index_col="Neighborhood")
neighborhood_locations_df.head()
# Out:
#                        Lat         Lon
# Neighborhood
# Alamo Square     37.791012 -122.402100
# Anza Vista       37.779598 -122.443451
# Bayview          37.734670 -122.401060
# Bayview Heights  37.728740 -122.410980
# Bernal Heights   37.728630 -122.443050

# %% [markdown]
# ##  Using the original sfo_data_df Dataframe, create a DataFrame named all_neighborhood_info_df that groups the data by neighborhood. Aggregate the results by the mean of the group.

# %%
# Calculating the mean values for each neighborhood
all_neighborhood_info_df = sfo_data_df.groupby("neighborhood").mean(["housing_units","gross_rent","sale_price_sqr_foot"])
all_neighborhood_info_df.head()
# Out:
#                         year  sale_price_sqr_foot  housing_units   gross_rent
# neighborhood
# Alamo Square     2013.000000           366.020712       378401.0  2817.285714
# Anza Vista       2013.333333           373.382198       379050.0  3031.833333
# Bayview          2012.000000           204.588623       376454.0  2318.400000
# Bayview Heights  2015.000000           590.792839       382295.0  3739.000000
# Bernal Heights   2013.500000           576.746488       379374.5  3080.333333

# %% [markdown]
# ## Review the two code cells that concatenate the neighborhood_locations_df DataFrame with the all_neighborhood_info_df DataFrame

# %%
# Using the Pandas `concat` function, join the 
# neighborhood_locations_df and the all_neighborhood_info_df DataFrame
# The axis of the concatenation is "columns".
# The concat function will automatially combine columns with
# identical information, while keeping the additional columns.
all_neighborhoods_df = pd.concat(
    [neighborhood_locations_df, all_neighborhood_info_df], 
    axis="columns",
    sort=False
)

# Review the resulting DataFrame
display(all_neighborhoods_df.head())
display(all_neighborhoods_df.tail())
# Out:
#                        Lat         Lon         year  sale_price_sqr_foot  \
# Alamo Square     37.791012 -122.402100  2013.000000           366.020712
# Anza Vista       37.779598 -122.443451  2013.333333           373.382198
# Bayview          37.734670 -122.401060  2012.000000           204.588623
# Bayview Heights  37.728740 -122.410980  2015.000000           590.792839
# Bernal Heights   37.728630 -122.443050          NaN                  NaN
#
#                  housing_units   gross_rent
# Alamo Square          378401.0  2817.285714
# Anza Vista            379050.0  3031.833333
# Bayview               376454.0  2318.400000
# Bayview Heights       382295.0  3739.000000
# Bernal Heights             NaN          NaN
#                       Lat        Lon    year  sale_price_sqr_foot  \
# Yerba Buena      37.79298 -122.39636  2012.5           576.709848
# Bernal Heights        NaN        NaN  2013.5           576.746488
# Downtown              NaN        NaN  2013.0           391.434378
# Ingleside             NaN        NaN  2012.5           367.895144
# Outer Richmond        NaN        NaN  2013.0           473.900773
#
#                  housing_units   gross_rent
# Yerba Buena           377427.5  2555.166667
# Bernal Heights        379374.5  3080.333333
# Downtown              378401.0  2817.285714
# Ingleside             377427.5  2509.000000
# Outer Richmond        378401.0  2817.285714

# %%
# Call the dropna function to remove any neighborhoods that do not have data
all_neighborhoods_df = all_neighborhoods_df.reset_index().dropna()

# Rename the "index" column as "Neighborhood" for use in the Visualization
all_neighborhoods_df = all_neighborhoods_df.rename(columns={"index": "Neighborhood"})

# Review the resulting DataFrame
display(all_neighborhoods_df.head())
display(all_neighborhoods_df.tail())
# Out:
#        Neighborhood        Lat         Lon         year  sale_price_sqr_foot  \
# 0      Alamo Square  37.791012 -122.402100  2013.000000           366.020712
# 1        Anza Vista  37.779598 -122.443451  2013.333333           373.382198
# 2           Bayview  37.734670 -122.401060  2012.000000           204.588623
# 3   Bayview Heights  37.728740 -122.410980  2015.000000           590.792839
# 5  Buena Vista Park  37.768160 -122.439330  2012.833333           452.680591
#
#    housing_units   gross_rent
# 0       378401.0  2817.285714
# 1       379050.0  3031.833333
# 2       376454.0  2318.400000
# 3       382295.0  3739.000000
# 5       378076.5  2698.833333
#           Neighborhood       Lat         Lon     year  sale_price_sqr_foot  \
# 68         West Portal  37.74026 -122.463880  2012.25           498.488485
# 69    Western Addition  37.79298 -122.435790  2012.50           307.562201
# 70  Westwood Highlands  37.73470 -122.456854  2012.00           533.703935
# 71       Westwood Park  37.73415 -122.457000  2015.00           687.087575
# 72         Yerba Buena  37.79298 -122.396360  2012.50           576.709848
#
#     housing_units   gross_rent
# 68      376940.75  2515.500000
# 69      377427.50  2555.166667
# 70      376454.00  2250.500000
# 71      382295.00  3959.000000
# 72      377427.50  2555.166667

# %% [markdown]
# ## Using hvPlot with GeoViews enabled, create a points plot for the all_neighborhoods_df DataFrame

# %%
# Create a plot to analyze neighborhood info
all_neighborhoods_df.hvplot.points('Lon','Lat',geo=True,color='gross_rent', size='sale_price_sqr_foot', tiles='OSM'
                                   ,hover_cols='all', title="Average Sale Price per Square foot and Gross Rent in SFO")
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lon,Lat]   (gross_rent,sale_price_sqr_foot,index,Neighborhood,year,housing_units)

# %% [markdown]
# ## Union Square District has the highest Average price as it is the largest circle and gross rent is highest in Sunnyside neighborhood as it is the darkest color

# %% [markdown]
# ## Data Story

# %% [markdown]
# ## 1) For almost all neighborhoods in SFO the rate of  increase in gross rent was higher as compared to increase in average priceper square foot
# ## 2)The company should be selective in chosing a neighborhood in which to implement its one click buy and rent strategy.The company should focus on neighborhoods where the cost to purchase is low and constant but the rent is increasing.
